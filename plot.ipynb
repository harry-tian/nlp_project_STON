# %%
import matplotlib.pyplot as plt
import csv
import numpy as np
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
import plot

# %%
title = "Accuracy: Name to entity cloze tasks using different pronouns"
plot.plot_cloze_names(title)

# %%
results = "cloze/simple_SVO/names/his_name/results.csv"
title = "\"his name is [MASK]\""
plot.plot_cloze(results, title)

# %%
results = "cloze/simple_SVO/names/her_name/results.csv"
title = "\"her name is [MASK]\""
plot.plot_cloze(results, title)

# %%
results = "cloze/simple_SVO/names/my_name/results.csv"
title = "\"my name is [MASK]\""
plot.plot_cloze(results, title)

# %%
results = "cloze/simple_SVO/names/your_name/results.csv"
title = "\"your name is [MASK]\""
plot.plot_cloze(results, title)

# %% [markdown]
# # accuracy plots

# %%
data_dir = "distractor"
title = "Accuracy: semantically related attractors"
plot.plot_acc(data_dir, title)

# %%
data_dir = "with_neutral_distractor"
title = "Accuracy: semantically unrelated attractors"
plot.plot_acc(data_dir, title)

# %% [markdown]
# # relative prob plots

# %%
data_dir = "distractor"
title = "Relative probability: semantically related attractors"
plot.plot_relative_prob(data_dir, title)

# %%
data_dir = "with_neutral_distractor"
title = "Relative probability: semantically unrelated attractors"
plot.plot_relative_prob(data_dir, title)
